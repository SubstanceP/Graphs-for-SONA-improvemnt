# %%
# Imports
# 
# Note: these are all the imports you need for this assignment!
# Do not import any other functions / packages

# Display plots directly in the notebook instead of in a new window
# %matplotlib inline

# Import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv("FinalProjectCSV.csv")

# %%
df
# Out:
#    Tech Experience Prior Sona Use  Enjoyed                 Suggestions
# 0       Proficient            Yes       No          Omit Pre-Screening
# 1       Proficient            Yes  Nuetral  Improve Study Descriptions
# 2       Proficient            Yes  Nuetral           Add Study Filters
# 3       Proficient            Yes      Yes          Omit Pre-Screening
# 4       Proficient            Yes       No           Add Study Filters
# 5       Proficient            Yes  Nuetral  Improve Study Descriptions
# 6       Proficient             No       No           Add Study Filters
# 7         Moderate            Yes       No          Omit Pre-Screening
# 8       Proficient            Yes       No          Omit Pre-Screening
# 9         Moderate            Yes       No           Add Study Filters
# 10        Moderate             No  Nuetral           Add Study Filters
# 11        Moderate            Yes      Yes           Add Study Filters
# ...

# %%
palette = sns.color_palette("bright")

sns.palplot(palette)

# %%
sns.set_palette("bright")

# %%
chart = sns.countplot(
    data=df,
    x="Suggestions"
)
chart.set_xticklabels(chart.get_xticklabels(), rotation=45, horizontalalignment='right', fontweight='light', fontsize='small')
# Out:
# [Text(0, 0, 'Omit Pre-Screening'),
#  Text(0, 0, 'Improve Study Descriptions'),
#  Text(0, 0, 'Add Study Filters')]

# %%
sns.countplot(x="Prior Sona Use", hue="Enjoyed", data=df)

# %%
sns.countplot(x="Tech Experience", hue="Enjoyed", data=df)

# %%
#sns.set_context("notebook", font_scale=1.5, rc={"lines.linewidth": 2.5})
#sns.set(xlim = (50000,250000))
#plt.figure(figsize=(15,5))
sns.catplot(x="Navigation to Events Page", hue="Type of User", kind="count", data=df);

# %%
plt.figure(figsize=(10,10))

LocSD = sns.countplot(
    data=df,
    y="Location Change - San Diego",
    hue="Type of User",
)
LocSD.set_ylabel('')
plt.title("Location Change - San Diego")
# Out:
# Text(0.5, 1.0, 'Location Change - San Diego')

# %%
plt.figure(figsize=(10,5.2))
chart = sns.countplot(
    data=df,
    x="Location Change - Santa Barbara",
    hue="Type of User",
)
chart.set_xticklabels(chart.get_xticklabels(), rotation=45, horizontalalignment='right', fontweight='light', fontsize='large')
# Out:
# [Text(0, 0, 'sub-optimal success'),
#  Text(0, 0, 'memory-lapse slip'),
#  Text(0, 0, 'action-based slip'),
#  Text(0, 0, 'optimal succes')]

# %%
plt.figure(figsize=(10,5.2))
chart = sns.countplot(
    data=df,
    x="Navigation to Politics Page",
    hue="Type of User",
)
chart.set_xticklabels(chart.get_xticklabels(), rotation=45, horizontalalignment='right', fontweight='light', fontsize='x-large')
# Out:
# [Text(0, 0, 'navigation filters'),
#  Text(0, 0, 'knowledge-based mistake'),
#  Text(0, 0, 'search bar'),
#  Text(0, 0, 'action-based mistake')]

# %%
plt.figure(figsize=(10,5.2))
chart = sns.countplot(
    data=df,
    x="Navigation to Events Page",
    hue="Type of User",
)
#chart.set_xticklabels(chart.get_xticklabels(), rotation=45, horizontalalignment='right', fontweight='light', fontsize='x-large')

# %%
plt.figure(figsize=(10,5.2))
chart = sns.countplot(
    data=df,
    x="BMW Search",
    hue="Type of User",
)
chart.set_xticklabels(chart.get_xticklabels(), rotation=45, horizontalalignment='right', fontweight='light', fontsize='x-large')
# Out:
# [Text(0, 0, 'action-based slip'),
#  Text(0, 0, 'memory-lapse mistake'),
#  Text(0, 0, 'optimal success'),
#  Text(0, 0, 'rule-based mistake')]

# %%
()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-986e25863b45> in <module>
# ----> 1 df.value_counts()
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'value_counts'

# %%
df['Type of User'].value_counts()
# Out:
# sufficiant user    7
# super user         6
# moderate user      2
# Name: Type of User, dtype: int64

# %%
df['Location Change - San Diego'].value_counts()
# Out:
# action-based slip          6
# sub-optimal success        4
# knowledge-based mistake    3
# memory-lapse slip          1
# optimal success            1
# Name: Location Change - San Diego, dtype: int64

# %%
df['Location Change - Santa Barbara'].value_counts()
# Out:
# sub-optimal success    8
# optimal succes         3
# action-based slip      2
# memory-lapse slip      2
# Name: Location Change - Santa Barbara, dtype: int64

# %%
df['Craigslist Experience'].value_counts()
# Out:
# sometimes     7
# never         5
# frequently    3
# Name: Craigslist Experience, dtype: int64

# %%
df['BMW Search'].value_counts()
# Out:
# action-based slip       6
# optimal success         5
# rule-based mistake      3
# memory-lapse mistake    1
# Name: BMW Search, dtype: int64

# %%
df['Navigation to Events Page'].value_counts()
# Out:
# events calendar      12
# action-based slip     3
# Name: Navigation to Events Page, dtype: int64

# %%
df['Navigation to Politics Page'].value_counts()
# Out:
# search bar                 5
# navigation filters         4
# action-based mistake       3
# knowledge-based mistake    3
# Name: Navigation to Politics Page, dtype: int64

# %%
sns.set_palette("bright")
plt.figure(figsize=(10,5.2))
chart = sns.countplot(
    data=df,
    x="Location Change - San Diego",
    hue="Craigslist Experience",
)
chart.set_xticklabels(chart.get_xticklabels(), rotation=45, horizontalalignment='right', fontweight='light', fontsize='large')
# Out:
# [Text(0, 0, 'action-based slip'),
#  Text(0, 0, 'sub-optimal success '),
#  Text(0, 0, 'memory-lapse slip'),
#  Text(0, 0, 'optimal success'),
#  Text(0, 0, 'knowledge-based mistake')]

# %%
sns.set_palette("bright")
plt.figure(figsize=(10,5.2))
chart = sns.countplot(
    data=df,
    x="Location Change - Santa Barbara",
    hue="Craigslist Experience",
)
chart.set_xticklabels(chart.get_xticklabels(), rotation=45, horizontalalignment='right', fontweight='light', fontsize='large')
# Out:
# [Text(0, 0, 'sub-optimal success'),
#  Text(0, 0, 'memory-lapse slip'),
#  Text(0, 0, 'action-based slip'),
#  Text(0, 0, 'optimal succes')]

# %%
sns.set_palette("bright")
plt.figure(figsize=(10,5.2))
chart = sns.countplot(
    data=df,
    x="Navigation to Events Page",
    hue="Craigslist Experience",
)
#chart.set_xticklabels(chart.get_xticklabels(), rotation=45, horizontalalignment='right', fontweight='light', fontsize='x-large')

# %%
sns.set_palette("bright")
plt.figure(figsize=(10,5.2))
chart = sns.countplot(
    data=df,
    x="Navigation to Politics Page",
    hue="Craigslist Experience",
)
#chart.set_xticklabels(chart.get_xticklabels(), rotation=45, horizontalalignment='right', fontweight='light', fontsize='x-large')

# %%
sns.set_palette("bright")
plt.figure(figsize=(10,5.2))
chart = sns.countplot(
    data=df,
    x="BMW Search",
    hue="Craigslist Experience",
)
#chart.set_xticklabels(chart.get_xticklabels(), rotation=45, horizontalalignment='right', fontweight='light', fontsize='x-large')
